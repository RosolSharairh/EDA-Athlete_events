# %% [markdown]
# # Importing Libraries.

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Uploading Dataset.

# %%
df = pd.read_csv('athlete_events.csv')

# %% [markdown]
# # Cleaning DataFrame

# %%
#cleaning Empty cells 
df['Age'].fillna((df['Age'].mean()), inplace=True)
df['Height'].fillna((df['Height'].mean()), inplace=True)
df['Weight'].fillna((df['Weight'].mean()), inplace=True)
df['Medal'].fillna('No Medal', inplace=True)
#removing duplicates
df.drop_duplicates(inplace = True)
#cleaning wrong format
df[['ID','Age','Height','Weight','Year']].apply(pd.to_numeric)
# Out:
#             ID   Age     Height     Weight  Year
# 0            1  24.0  180.00000  80.000000  1992
# 1            2  23.0  170.00000  60.000000  2012
# 2            3  24.0  175.33897  70.702393  1920
# 3            4  34.0  175.33897  70.702393  1900
# 4            5  21.0  185.00000  82.000000  1988
# ...        ...   ...        ...        ...   ...
# 271111  135569  29.0  179.00000  89.000000  1976
# 271112  135570  27.0  176.00000  59.000000  2014
# 271113  135570  27.0  176.00000  59.000000  2014
# 271114  135571  30.0  185.00000  96.000000  1998
# 271115  135571  34.0  185.00000  96.000000  2002
#
# [269731 rows x 5 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# ID        0
# Name      0
# Sex       0
# Age       0
# Height    0
# Weight    0
# Team      0
# NOC       0
# Games     0
# Year      0
# Season    0
# City      0
# Sport     0
# Event     0
# Medal     0
# dtype: int64

# %% [markdown]
# #Observing Data.

# %%
df.head(5)
# Out:
#    ID                      Name Sex   Age     Height     Weight  \
# 0   1                 A Dijiang   M  24.0  180.00000  80.000000
# 1   2                  A Lamusi   M  23.0  170.00000  60.000000
# 2   3       Gunnar Nielsen Aaby   M  24.0  175.33897  70.702393
# 3   4      Edgar Lindenau Aabye   M  34.0  175.33897  70.702393
# 4   5  Christine Jacoba Aaftink   F  21.0  185.00000  82.000000
#
#              Team  NOC        Games  Year  Season       City          Sport  \
# 0           China  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1           China  CHN  2012 Summer  2012  Summer     London           Judo
# 2         Denmark  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4     Netherlands  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event     Medal
# 0       Basketball Men's Basketball  No Medal
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 269731 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      269731 non-null  int64
#  1   Name    269731 non-null  object
#  2   Sex     269731 non-null  object
#  3   Age     269731 non-null  float64
#  4   Height  269731 non-null  float64
#  5   Weight  269731 non-null  float64
#  6   Team    269731 non-null  object
#  7   NOC     269731 non-null  object
#  8   Games   269731 non-null  object
#  9   Year    269731 non-null  int64
#  10  Season  269731 non-null  object
#  11  City    269731 non-null  object
#  12  Sport   269731 non-null  object
#  13  Event   269731 non-null  object
#  14  Medal   269731 non-null  object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 32.9+ MB

# %%
df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  269731.000000  269731.000000  269731.000000  269731.000000
# mean    68264.949591      25.458303     175.338957      70.701918
# std     39026.253843       6.056530       9.301313      12.606697
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34655.500000      22.000000     170.000000      63.000000
# 50%     68233.000000      25.000000     175.338970      70.702393
# 75%    102111.000000      28.000000     180.000000      76.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  269731.000000
# mean     1978.623073
# std        29.752055
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %% [markdown]
# # Cities who have hosted the Olympics for more than one time

# %%
city = df.groupby('City').apply(lambda x:x['Year'].unique()).to_frame().reset_index()
city.columns = ['City','Years']
city['Occurence'] = [len(c) for c in city['Years']]
print(city.loc[city['Occurence']>1].sort_values('Occurence',ascending=False))
# Out:
#             City               Years  Occurence
# 3         Athina  [2004, 1906, 1896]          3
# 17        London  [2012, 1948, 1908]          3
# 14     Innsbruck        [1964, 1976]          2
# 15   Lake Placid        [1980, 1932]          2
# 18   Los Angeles        [1932, 1984]          2
# 26         Paris        [1900, 1924]          2
# 30  Sankt Moritz        [1928, 1948]          2
# 37     Stockholm        [1912, 1956]          2

# %%
sns.histplot(city['Occurence'])

# %% [markdown]
# # Finding the participation of men snd women at the Olympic games

# %%
plt.figure(figsize=(50,10))
sns.displot(data=df , x='Year' ,col ="Sex" )

# %%
plt.figure(figsize=(20,6))
sns.histplot(x=df['Year'] , hue=df['Sex'], hue_order='F')
#for 50 years women were nearly not participating in the olympics

# %%
sns.displot(data=df , x='Medal' ,hue='Sex' )
#men win medals two times more than women

# %% [markdown]
# # sports having the most female gold medalists

# %%
gold = df[df['Medal']=='Gold']
femaleGold = gold[gold['Sex']=='F'].groupby('Sport').count().sort_values(['Medal'],ascending=False)
femaleGold['Medal'].head().plot(x = 'Sport', y = 'Medal', kind = 'bar', figsize = (15,5))

# %% [markdown]
# # Variation in counts between Summer and Winter.

# %%
sns.displot(data=df , x='Season' , hue='Sex' , hue_order=['F','M'])

# %% [markdown]
# # Age,Height and Weight Distribution.

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Age'],color='Green')
df['Age'].mode()
# Out:
# 0    23.0
# dtype: float64

# %%
plt.figure(figsize=(15,6))
sns.violinplot(x=df['Weight'],color='Pink')
df['Weight'].mode()
# Out:
# 0    70.702393
# dtype: float64

# %%
plt.figure(figsize=(15,6))
sns.violinplot(x=df['Height'],color='Gray')
df['Height'].mode()
# Out:
# 0    175.33897
# dtype: float64

# %% [markdown]
# # Top ten Sports having most number of medals

# %%
data=[]
for Sport in df['Sport'].unique():
  data.append([Sport,len(df[df['Sport']==Sport])])
pd.DataFrame(data,columns =['Sport','Medal']).sort_values(by='Medal',ascending=False).head(10).plot(x = 'Sport', y = 'Medal', kind = 'bar',figsize = (10,10))

# %%
data = []
for Athlete in df['Name'].unique():
    data.append([Athlete , len(df[df['Name']  == Athlete])])

pd.DataFrame(data,columns = ['Athlete','Frequencies']).sort_values(by='Frequencies', ascending=False).head().plot(x = 'Athlete', y = 'Frequencies', kind = 'bar', figsize = (15,5))

# %% [markdown]
# # The most popular Sports in terms on number of players .

# %%
data = []

for Event in df['Event'].unique():
    data.append([Event , len(df[df['Event']  == Event])])

pd.DataFrame(data,columns = ['Event','Frequencies']).sort_values(by='Frequencies', ascending=False).head(10).plot(x = 'Event', y = 'Frequencies', kind = 'bar', figsize = (15,5))

# %% [markdown]
# # Else

# %%
corelation=df.corr()
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)

# %%
plt.figure(figsize=(20,6))
sns.pairplot(df[['Age','Height','Weight']])

# %%
sns.relplot(x='Year', y='Age', hue='Sex',data=df)
